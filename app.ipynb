# %%
# Import necessary packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from matplotlib import colormaps as cmaps
from mpl_toolkits.mplot3d import Axes3D

# %%
# Read the dataset csv file with pandas
fruits = pd.read_table('datasets/fruit_data_with_colours.csv', sep=',')
fruits.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
# Spliting the dataset into train and test sets for input and target label
X = fruits[['mass','width','height','color_score']]
y = fruits['fruit_label']

# 75% for training, 25% for testing
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

print(f'Shape fruits:  {fruits.shape}')
print(f'Shape X_train: {X_train.shape}')
print(f'Shape X_test:  {X_test.shape}')
print(f'Shape y_train: {y_train.shape}')
print(f'Shape y_test:  {y_test.shape}')
# Out:
# Shape fruits:  (59, 7)
# Shape X_train: (44, 4)
# Shape X_test:  (15, 4)
# Shape y_train: (44,)
# Shape y_test:  (15,)

# %%
# Data visualization in 2-D in order to pre-analise data and define preprocessing methods
cmap    = cmaps.get_cmap('gnuplot')
scatter = pd.plotting.scatter_matrix(X_train, c=y_train, marker='o', s=40, hist_kwds={'bins':15}, figsize=(12,12), cmap=cmap)

# %%
# Data visualization in 3-D
fig = plt.figure()
ax  = fig.add_subplot(111, projection='3d')
ax.scatter(X_train['width'], X_train['height'], X_train['color_score'], c=y_train, marker='o', s=100)
ax.set_xlabel('width')
ax.set_ylabel('height')
ax.set_zlabel('color_score')
plt.show()
